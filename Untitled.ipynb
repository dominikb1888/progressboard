# %%
import requests as rq
import pandas as pd


url = 'http://127.0.0.1:5000/api/v1/users'
data = rq.get(url).json()

for user in data:
    df = pd.DataFrame(user)
    display(df)
# Out:
#     commits  completed exercise  failed  \
# 0         5          1       01       1
# 1         4          1       08       1
# 2         4          1       02       1
# 3         5          1       03       1
# 4         4          1       03       1
# 5         4          1       04       1
# 6         4          1       05       1
# 7         4          1       06       1
# 8         4          1       07       1
# 9         4          1       01       1
# 10        4          1       02       1
# 11        4          1       03       1
# 12        4          1       04       1
# 13        4          1       05       1
# 14        4          1       06       1
# 15        4          1       07       1
# 16        5          2       08       2
# 17        4          1       09       1
# 18        5          2       10       2
# 19        3          0       11       0
# 20        4          1       12       1
# 21        4          1       09       1
# ...
